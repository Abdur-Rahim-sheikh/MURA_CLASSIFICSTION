# %%
import tensorflow as tf
import os
import pandas as pd
import cv2
from skimage.transform import rescale, resize
from tensorflow import keras
import numpy as np
from sklearn.utils import class_weight
import tensorflow_addons as tfa
import pickle
from skimage.io import imread
from sklearn.utils import shuffle
from matplotlib import pyplot as plt
# Out:
# 2021-09-28 14:08:46.773634: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
def filenames(part,train=True):
    root='../input/mura-v11/'
    if train:
        csv_path="../input/mura-v11/MURA-v1.1/train_image_paths.csv"
    else:
        csv_path="../input/mura-v11/MURA-v1.1/valid_image_paths.csv"
    
    with open(csv_path, 'rb') as F:
        d = F.readlines()
#         print(str(d[0],encoding='utf-8').strip())
        if part == 'all':
            imgs = [root + str(x, encoding='utf-8').strip() for x in d]  # 所有图片的存储路径, [:-1]目的是抛弃最末尾的\n
        else:
            imgs = [root + str(x, encoding='utf-8').strip() for x in d if
                            str(x, encoding='utf-8').strip().split('/')[2] == part]

#     imgs= [x.replace("/", "\\") for x in imgs]
    labels= [x.split('_')[-1].split('/')[0] for x in imgs]
#     print("self testing:",imgs[:5],labels[:5])
    return imgs,labels

# %%
def crop_center(img,cropx,cropy):
    y,x,_ = img.shape
    startx = x//2-(cropx//2)
    starty = y//2-(cropy//2)    
    return img[starty:starty+cropy,startx:startx+cropx]

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)
# from albumentations.augmentations.transforms import Resize
AUGMENTATIONS_TRAIN = Compose([
    HorizontalFlip(p=0.5),
    RandomContrast(limit=0.2, p=0.5),
    RandomGamma(gamma_limit=(80, 120), p=0.5),
    RandomBrightness(limit=0.2, p=0.5),
    ShiftScaleRotate(
        shift_limit=0.0625, scale_limit=0.1, 
        rotate_limit=15, border_mode=cv2.BORDER_REFLECT_101, p=0.8), 
    ToFloat(max_value=255)
])
AUGMENTATIONS_TEST = Compose([
    # CLAHE(p=1.0, clip_limit=2.0),
    ToFloat(max_value=255)
])
# Out:
# /opt/conda/lib/python3.7/site-packages/albumentations/augmentations/transforms.py:1772: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,
# /opt/conda/lib/python3.7/site-packages/albumentations/augmentations/transforms.py:1746: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,

# %%
albumentation_list =  [
    HorizontalFlip(p=0.5),
    RandomContrast(limit=0.2, p=0.5),
    RandomGamma(gamma_limit=(80, 120), p=0.5),
    RandomBrightness(limit=0.2, p=0.5),
    ShiftScaleRotate(
        shift_limit=0.0625, scale_limit=0.1, 
        rotate_limit=15, border_mode=cv2.BORDER_REFLECT_101, p=0.8), 
    ToFloat(max_value=255)
]
root='../input/mura-v11/'
chosen_image= imread(root+'MURA-v1.1/train/XR_ELBOW/patient01055/study1_positive/image3.png')
img_matrix_list = []
bboxes_list = []
for aug_type in albumentation_list:
    img = aug_type(image = chosen_image)['image']
    img_matrix_list.append(img)
img= resize(chosen_image,(300,300,3))
img_matrix_list.append(img)
img_matrix_list.append(crop_center(img,224,224))

img_matrix_list.insert(0,chosen_image)    

titles_list = ["Original","Horizontal Flip","Random Contrast","Random Gamma","RandomBrightness",
               "Shift Scale Rotate","Resizing", "Cropping"]

# %%
def plot_multiple_img(img_matrix_list, title_list, ncols, main_title="Data Augmentation"):
    fig, myaxes = plt.subplots(figsize=(20, 15), nrows=2, ncols=ncols, squeeze=True)
    fig.suptitle(main_title, fontsize = 30)
    #fig.subplots_adjust(wspace=0.3)
    #fig.subplots_adjust(hspace=0.3)
    for i, (img, title) in enumerate(zip(img_matrix_list, title_list)):
        myaxes[i // ncols][i % ncols].imshow(img)
        myaxes[i // ncols][i % ncols].set_title(title, fontsize=15)
    plt.show()
    
plot_multiple_img(img_matrix_list, titles_list, ncols = 4)

# %%
class My_Custom_Generator(keras.utils.Sequence) :
    def __init__(self, image_filenames, labels, batch_size,transform) :
        self.image_filenames = image_filenames
        self.labels = labels
        self.batch_size = batch_size
        self.t= transform
    
    def __len__(self) :
        return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
    
    def __getitem__(self, idx) :
        batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
        x=[]
        for file in batch_x:
            img= imread(file)
            img= self.t(image=img)["image"]
            img= resize(img,(300,300,3))
            img= crop_center(img,224,224)
            x.append(img)
        x=np.array(x)/255.0
        y= np.array(batch_y)
        return x,y

# %%
part='XR_WRIST'
imgs,labels= filenames(part=part)
vimgs,vlabels= filenames(part=part,train=False)
print(labels.count('positive'),labels.count('negative'))
training_data= labels.count('positive')+labels.count('negative')
print("Training Data: ", training_data)
y_data= [0 if x=='positive' else 1 for x in labels]
# print(y_data[-1:-5:-1])
y_data= keras.utils.to_categorical(y_data)
# print(y_data[-1:-5:-1])
print(vlabels.count('positive'),vlabels.count('negative'))
validation_data= vlabels.count('positive')+vlabels.count('negative')
print("Validation Data: ", validation_data)
vy_data= [0 if x=='positive' else 1 for x in vlabels]
vy_data= keras.utils.to_categorical(vy_data)
# Out:
# 3987 5765
# Training Data:  9752
# 295 364
# Validation Data:  659

# %%
# np.argmax(y_data,axis=1)

# %%
from sklearn.utils.class_weight import compute_class_weight

y_integers = np.argmax(y_data, axis=1)
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_integers), y=y_integers)
d_class_weights = dict(enumerate(class_weights))

# %%
batch_size = 32
imgs, y_data = shuffle(imgs, y_data)
#vimgs, vy_data = shuffle(vimgs, vy_data)
my_training_batch_generator = My_Custom_Generator(imgs, y_data, batch_size,AUGMENTATIONS_TRAIN)
my_validation_batch_generator = My_Custom_Generator(vimgs, vy_data, batch_size,AUGMENTATIONS_TEST)

# %%
part='XR_WRIST'
checkpoint_path = "WRIST.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)
my_callbacks = [
    keras.callbacks.ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=0, save_best_only=True,
                                       save_weights_only=False, mode='auto'),
    keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.1,patience=3,
                                         min_delta=0.001, verbose=1, min_lr=0.000000001)]

# %%
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
Inception=tf.keras.applications.InceptionV3(include_top=False,input_shape=(224,224,3))
    #for layer in Inception.layers[:4]:
    #  layer.trainable=False
input_image=keras.layers.Input((224,224,3))
x=Inception (input_image)

    #x=keras.layers.GlobalAveragePooling2D()(x)
x=keras.layers.Flatten()(x)
    #x=keras.layers.Dense(1024)(x)
    #x=keras.layers.Activation(activation='relu')(x)
    #x= keras.layers.Dropout(0.5)(x)
x=keras.layers.Dense(256)(x)
x=keras.layers.Activation(activation='relu')(x)
x= keras.layers.Dropout(0.5)(x)
x=keras.layers.Dense(2)(x)
out=keras.layers.Activation(activation='softmax')(x)


model=keras.Model(inputs=input_image,outputs=out)
model.compile(optimizer=keras.optimizers.RMSprop(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
print(model.summary())
# Out:
# 2021-09-28 14:08:53.779515: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-28 14:08:53.782670: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-28 14:08:53.821011: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:53.821648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-28 14:08:53.821695: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-28 14:08:53.857248: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-28 14:08:53.857334: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-28 14:08:53.874439: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-28 14:08:53.882937: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-28 14:08:53.907681: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-28 14:08:53.916248: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-28 14:08:53.919028: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-28 14:08:53.919197: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:53.919877: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:53.921362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-28 14:08:53.921967: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-28 14:08:53.922158: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-28 14:08:53.922321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:53.922943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-28 14:08:53.922989: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-28 14:08:53.923029: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-28 14:08:53.923067: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-28 14:08:53.923092: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-28 14:08:53.923118: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-28 14:08:53.923154: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-28 14:08:53.923186: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-28 14:08:53.923212: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-28 14:08:53.923306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:53.923963: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:53.924516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-28 14:08:53.925848: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-28 14:08:55.471385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-28 14:08:55.471430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-28 14:08:55.471440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-28 14:08:55.473980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:55.474841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:55.475566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-28 14:08:55.476152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# activation_94 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# _________________________________________________________________
# activation_95 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 34,910,754
# Trainable params: 34,876,322
# Non-trainable params: 34,432
# _________________________________________________________________
# None

# %%
my_callbacks,d_class_weights
# Out:
# ([<tensorflow.python.keras.callbacks.ModelCheckpoint at 0x7febec3f7050>,
#   <tensorflow.python.keras.callbacks.ReduceLROnPlateau at 0x7febec3f7150>],
#  {0: 1.2229746676699274, 1: 0.8457935819601041})

# %%
history=model.fit_generator(generator=my_training_batch_generator,
                   steps_per_epoch = int(training_data // batch_size),
                   epochs = 30,
                   verbose = 1,
                   class_weight=d_class_weights,
                   validation_data = my_validation_batch_generator,
                   validation_steps = int(validation_data // batch_size),
                   callbacks=my_callbacks)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021-09-28 14:09:01.060348: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-28 14:09:01.064378: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000179999 Hz
# Epoch 1/30
# 2021-09-28 14:09:10.704472: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-28 14:09:11.685109: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-28 14:09:12.638246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 304/304 [==============================] - 650s 2s/step - loss: 0.8974 - accuracy: 0.6669 - val_loss: 0.7188 - val_accuracy: 0.5203
# Epoch 2/30
# 304/304 [==============================] - 580s 2s/step - loss: 0.4421 - accuracy: 0.8248 - val_loss: 0.9312 - val_accuracy: 0.7688
# Epoch 3/30
# 304/304 [==============================] - 577s 2s/step - loss: 0.4207 - accuracy: 0.8410 - val_loss: 0.7410 - val_accuracy: 0.8219
# Epoch 4/30
# 304/304 [==============================] - 580s 2s/step - loss: 0.4113 - accuracy: 0.8475 - val_loss: 1.0602 - val_accuracy: 0.7312
# Epoch 5/30
# 304/304 [==============================] - 586s 2s/step - loss: 0.3767 - accuracy: 0.8620 - val_loss: 1.4648 - val_accuracy: 0.7953
# Epoch 6/30
# 304/304 [==============================] - 597s 2s/step - loss: 0.3737 - accuracy: 0.8724 - val_loss: 1.5319 - val_accuracy: 0.8281
# Epoch 7/30
# 304/304 [==============================] - 593s 2s/step - loss: 0.3485 - accuracy: 0.8728 - val_loss: 1.2166 - val_accuracy: 0.7688
# Epoch 8/30
# 304/304 [==============================] - 591s 2s/step - loss: 0.4051 - accuracy: 0.8717 - val_loss: 10.2567 - val_accuracy: 0.7281
# Epoch 9/30
# 304/304 [==============================] - 596s 2s/step - loss: 0.3681 - accuracy: 0.8742 - val_loss: 1.1100 - val_accuracy: 0.8344
# Epoch 10/30
# 304/304 [==============================] - 590s 2s/step - loss: 0.3348 - accuracy: 0.8752 - val_loss: 3.6203 - val_accuracy: 0.8391
# Epoch 11/30
# 304/304 [==============================] - 599s 2s/step - loss: 0.3273 - accuracy: 0.8807 - val_loss: 1.2045 - val_accuracy: 0.8094
# Epoch 12/30
# 304/304 [==============================] - 593s 2s/step - loss: 0.3250 - accuracy: 0.8845 - val_loss: 0.6184 - val_accuracy: 0.8313
# Epoch 14/30
# 304/304 [==============================] - 603s 2s/step - loss: 0.3327 - accuracy: 0.8925 - val_loss: 6.7753 - val_accuracy: 0.7984
# Epoch 15/30
# 304/304 [==============================] - 605s 2s/step - loss: 0.2823 - accuracy: 0.8973 - val_loss: 3.2237 - val_accuracy: 0.8313
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 16/30
# 304/304 [==============================] - 602s 2s/step - loss: 0.2321 - accuracy: 0.9188 - val_loss: 0.6315 - val_accuracy: 0.8422
# Epoch 17/30
# 304/304 [==============================] - 619s 2s/step - loss: 0.2165 - accuracy: 0.9179 - val_loss: 0.8439 - val_accuracy: 0.8453
# Epoch 18/30
# 304/304 [==============================] - 601s 2s/step - loss: 0.1896 - accuracy: 0.9318 - val_loss: 0.7405 - val_accuracy: 0.8438
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 19/30
# 304/304 [==============================] - 597s 2s/step - loss: 0.1821 - accuracy: 0.9309 - val_loss: 0.6510 - val_accuracy: 0.8422
# Epoch 20/30
# 304/304 [==============================] - 593s 2s/step - loss: 0.1762 - accuracy: 0.9349 - val_loss: 0.6452 - val_accuracy: 0.8406
# Epoch 21/30
# 304/304 [==============================] - 594s 2s/step - loss: 0.1840 - accuracy: 0.9298 - val_loss: 0.6716 - val_accuracy: 0.8469
# Epoch 22/30
# 304/304 [==============================] - 592s 2s/step - loss: 0.1873 - accuracy: 0.9333 - val_loss: 0.6630 - val_accuracy: 0.8453
# Epoch 23/30
# 304/304 [==============================] - 591s 2s/step - loss: 0.1738 - accuracy: 0.9338 - val_loss: 0.6845 - val_accuracy: 0.8453
# Epoch 24/30
# 304/304 [==============================] - 595s 2s/step - loss: 0.1829 - accuracy: 0.9336 - val_loss: 0.6974 - val_accuracy: 0.8453
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 25/30
# 304/304 [==============================] - 596s 2s/step - loss: 0.1713 - accuracy: 0.9327 - val_loss: 0.6991 - val_accuracy: 0.8453
# Epoch 26/30
# 304/304 [==============================] - 596s 2s/step - loss: 0.1791 - accuracy: 0.9331 - val_loss: 0.6997 - val_accuracy: 0.8438
# Epoch 27/30
# 304/304 [==============================] - 596s 2s/step - loss: 0.1791 - accuracy: 0.9372 - val_loss: 0.6999 - val_accuracy: 0.8438
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 28/30
# 304/304 [==============================] - 601s 2s/step - loss: 0.1630 - accuracy: 0.9394 - val_loss: 0.6917 - val_accuracy: 0.8438
# Epoch 29/30
# 304/304 [==============================] - 603s 2s/step - loss: 0.1683 - accuracy: 0.9358 - val_loss: 0.6885 - val_accuracy: 0.8438
# Epoch 30/30
# 304/304 [==============================] - 602s 2s/step - loss: 0.1772 - accuracy: 0.9329 - val_loss: 0.7005 - val_accuracy: 0.8438
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-09.

# %%
m = tfa.metrics.CohenKappa(num_classes=2,sparse_labels=False)
model=tf.keras.models.load_model(checkpoint_path)
y_pred=  model.predict(my_validation_batch_generator)

yp2 = np.argmax(y_pred,axis = 1)
ya2 = np.argmax(vy_data,axis = 1)
print(y_pred.shape,vy_data.shape)
m.update_state(ya2, yp2)
print('Final result: ', m.result().numpy())
# Out:
# (659, 2) (659, 2)
# Final result:  0.6899582
